# %% [markdown]
# <a href="https://colab.research.google.com/github/KiranGaikwad2020/Data_Sciecne_Lab/blob/master/BasicOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

# Addition
print(f"Addition: {a} + {b} = {a + b}")

# Subtraction
print(f"Subtraction: {a} - {b} = {a - b}")

# Multiplication
print(f"Multiplication: {a} * {b} = {a * b}")

# Division
print(f"Division: {a} / {b} = {a / b}")

# Floor Division (integer division)
print(f"Floor Division: {a} // {b} = {a // b}")

# Modulus (remainder)
print(f"Modulus: {a} % {b} = {a % b}")

# Exponentiation
print(f"Exponentiation: {a} ** {b} = {a ** b}")
# Out:
# Enter the first number: 10
# Enter the second number: 20
# Addition: 10 + 20 = 30
# Subtraction: 10 - 20 = -10
# Multiplication: 10 * 20 = 200
# Division: 10 / 20 = 0.5
# Floor Division: 10 // 20 = 0
# Modulus: 10 % 20 = 10
# Exponentiation: 10 ** 20 = 100000000000000000000

# %%
a = 10
b = 5

# Addition
print(f"Addition: {a} + {b} = {a + b}")

# Subtraction
print(f"Subtraction: {a} - {b} = {a - b}")

# Multiplication
print(f"Multiplication: {a} * {b} = {a * b}")

# Division
print(f"Division: {a} / {b} = {a / b}")

# Floor Division (integer division)
print(f"Floor Division: {a} // {b} = {a // b}")

# Modulus (remainder)
print(f"Modulus: {a} % {b} = {a % b}")

# Exponentiation
print(f"Exponentiation: {a} ** {b} = {a ** b}")
# Out:
# Addition: 10 + 5 = 15
# Subtraction: 10 - 5 = 5
# Multiplication: 10 * 5 = 50
# Division: 10 / 5 = 2.0
# Floor Division: 10 // 5 = 2
# Modulus: 10 % 5 = 0
# Exponentiation: 10 ** 5 = 100000
